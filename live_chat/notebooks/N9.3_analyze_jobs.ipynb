# %%
# !pip install strands-agents[mistral] python-dotenv dictdiffer
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting dictdiffer
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting strands-agents[mistral]
#   Downloading strands_agents-1.13.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from strands-agents[mistral]) (1.40.52)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from strands-agents[mistral]) (1.40.52)
# Collecting docstring-parser<1.0,>=0.15 (from strands-agents[mistral])
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting mcp<2.0.0,>=1.11.0 (from strands-agents[mistral])
#   Downloading mcp-1.19.0-py3-none-any.whl.metadata (85 kB)
# Collecting opentelemetry-api<2.0.0,>=1.30.0 (from strands-agents[mistral])
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 (from strands-agents[mistral])
#   Downloading opentelemetry_instrumentation_threading-0.59b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.30.0 (from strands-agents[mistral])
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from strands-agents[mistral]) (2.12.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from strands-agents[mistral]) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from strands-agents[mistral]) (6.0.0)
# Collecting mistralai>=1.8.2 (from strands-agents[mistral])
#   Downloading mistralai-1.9.11-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents[mistral]) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents[mistral]) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents[mistral]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents[mistral]) (2.5.0)
# Requirement already satisfied: anyio>=4.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (4.11.0)
# Collecting httpx-sse>=0.4 (from mcp<2.0.0,>=1.11.0->strands-agents[mistral])
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting httpx>=0.27.1 (from mcp<2.0.0,>=1.11.0->strands-agents[mistral])
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (4.25.1)
# Collecting pydantic-settings>=2.5.2 (from mcp<2.0.0,>=1.11.0->strands-agents[mistral])
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting python-multipart>=0.0.9 (from mcp<2.0.0,>=1.11.0->strands-agents[mistral])
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<2.0.0,>=1.11.0->strands-agents[mistral])
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: starlette>=0.27 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (0.37.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents[mistral]) (6.11.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents[mistral]) (3.23.0)
# Collecting opentelemetry-instrumentation==0.59b0 (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[mistral])
#   Downloading opentelemetry_instrumentation-0.59b0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[mistral]) (1.17.3)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[mistral])
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging>=18.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[mistral]) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[mistral]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[mistral]) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[mistral]) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents[mistral]) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (1.3.1)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (2025.10.5)
# Collecting httpcore==1.* (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents[mistral])
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: h11>=0.16 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (0.27.1)
# Collecting eval-type-backport>=0.2.0 (from mistralai>=1.8.2->strands-agents[mistral])
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting invoke<3.0.0,>=2.2.0 (from mistralai>=1.8.2->strands-agents[mistral])
#   Downloading invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from mistralai>=1.8.2->strands-agents[mistral]) (6.0.3)
# Requirement already satisfied: click>=7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents[mistral]) (8.3.0)
# Downloading strands_agents-1.13.0-py3-none-any.whl (223 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading mcp-1.19.0-py3-none-any.whl (170 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_instrumentation_threading-0.59b0-py3-none-any.whl (9.3 kB)
# Downloading opentelemetry_instrumentation-0.59b0-py3-none-any.whl (33 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading mistralai-1.9.11-py3-none-any.whl (442 kB)
# Downloading invoke-2.2.1-py3-none-any.whl (160 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Installing collected packages: dictdiffer, python-multipart, python-dotenv, invoke, httpx-sse, httpcore, eval-type-backport, docstring-parser, opentelemetry-api, sse-starlette, pydantic-settings, opentelemetry-semantic-conventions, httpx, opentelemetry-sdk, opentelemetry-instrumentation, mistralai, mcp, opentelemetry-instrumentation-threading, strands-agents
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [strands-agents]m [strands-agents]gs]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.3.3 which is incompatible.
# Successfully installed dictdiffer-0.9.0 docstring-parser-0.17.0 eval-type-backport-0.2.2 httpcore-1.0.9 httpx-0.28.1 httpx-sse-0.4.3 invoke-2.2.1 mcp-1.19.0 mistralai-1.9.11 opentelemetry-api-1.38.0 opentelemetry-instrumentation-0.59b0 opentelemetry-instrumentation-threading-0.59b0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pydantic-settings-2.11.0 python-dotenv-1.1.1 python-multipart-0.0.20 sse-starlette-3.0.2 strands-agents-1.13.0

# %%
import json
import os
import sys
import dotenv
import boto3
import requests
from collections import Counter
import yaml

import copy

from datetime import datetime

import pprint

import yaml
from pathlib import Path
from typing import Dict, List, Optional, Tuple, TypeVar
from tqdm import tqdm

# Pydantic for structured data
from pydantic import BaseModel, Field

# AWS authentication
from botocore.auth import SigV4Auth
from botocore.awsrequest import AWSRequest

sys.path.append('..')

from src.utils import (
    save_json,
    read_json,
    load_file_content,
    get_job_paths,
    get_training_paths,
    sanity_check,
    chat_with_persona,
    validate_submission_format,
    track_api_call,  # Cost tracking from utils
    print_cost_summary,  # Cost summary from utils
    reset_cost_tracker  # Reset cost tracker from utils
)

from src.my_utils import (
    display_markdown_file,
    call_mistral,
    get_agent,
    batch_extract,
    compute_stat_for_multi_items
)

from src.models.persona_info import PersonaInfo
from src.models.job_info import JobInfo
from src.models.training_info import TrainingInfo
from src.models.generic_models import (
    BooleanModel,
    BooleanModelWithRationale,
    ListOfIds
)

from src.prompts.find_training_matches_prompt import (
    FIND_TRAINING_MATCHES_PROMPT,
    FIND_TRAINING_MATCHES_PROMPT_BY_NAME,
    CHECK_PERSONA_TRAINING_MATCH,
    FIND_TRAINING_MATCHES_FOR_JOB_PROMPT
)

from src.prompts.find_job_matches_prompt import (
    FIND_JOB_MATCHES_PROMPT
)

# %%
DATA_JOBS_DIR = Path('../data_jobs')

# %%
with open("../src/config.yaml", "r") as f:
    config = yaml.safe_load(f)

job_data_version = config["job_data_version"]
print(f"job_data_version version: {job_data_version}")
# Out:
# job_data_version version: v4

# %%
# Load Jobs data
filename = f"final_jobs_{job_data_version}.json"
#filename = f"final_jobs_{job_data_version}.json"
jobs_save_path = DATA_JOBS_DIR / filename

jobs_data = read_json(jobs_save_path)

# Convert to JobInfo objects
jobs_info = {
    job_id: JobInfo.model_validate_json(data)
    for job_id, data in jobs_data.items()
}

print(f"✅ Loaded {len(jobs_info)} jobs")
print("\n" + "="*50)
# Out:
# ✅ Loaded 200 jobs
#
# ==================================================

# %%
def compute_job_data_stastistics(jobs_data):
    # Extract infos from the dictionary
    work_types = []
    education_level_requireds = []
    years_of_experience_requireds = []
    for job_data in jobs_data.values():
        data = json.loads(job_data)
        work_types.append(data['work_type'])
        education_level_requireds.append(data['education_level_required'])
        years_of_experience_requireds.append(data['years_of_experience_required'])

    type_counts = Counter(work_types)
    print("\n" + "="*50)
    print("\nwork_types Counts:")
    for type_name, count in type_counts.most_common():
        print(f"{type_name}: {count}")
    print(f"\nTotal count: {sum(type_counts.values())}")

    type_counts = Counter(education_level_requireds)
    print("\n" + "="*50)
    print("\neducation_level_requireds Counts:")
    for type_name, count in type_counts.most_common():
        print(f"{type_name}: {count}")
    print(f"\nTotal count: {sum(type_counts.values())}")

    type_counts = Counter(years_of_experience_requireds)
    print("\n" + "="*50)
    print("\nyears_of_experience_requireds Counts:")
    for type_name, count in type_counts.most_common():
        print(f"{type_name}: {count}")
    print(f"\nTotal count: {sum(type_counts.values())}")

    item_counts = compute_stat_for_multi_items(jobs_data, 'required_languages', include_values=False)
    print("\n" + "="*50)
    print("\nRequired Languages Counts:")
    print(f"\nTotal occurrences: {sum(item_counts.values())}")
    print(f"Total unique languages: {len(item_counts)}")
    for item, count in item_counts.most_common():
        print(f"{item}: {count}")

# %%
compute_job_data_stastistics(jobs_data)
# Out:
# ==================================================
#
# work_types Counts:
# onsite: 158
# remote: 42
#
# Total count: 200
#
# ==================================================
#
# education_level_requireds Counts:
# Graduação: 81
# Técnico: 60
# Tecnólogo: 53
# Bacharelado: 6
#
# Total count: 200
#
# ==================================================
#
# years_of_experience_requireds Counts:
# 1: 61
# 2: 59
# 0: 46
# 3: 34
#
# Total count: 200
#
# ==================================================
#
# Required Languages Counts:
#
# Total occurrences: 254
# Total unique languages: 2
# Portuguese: 200
# English: 54

# %% [markdown]
# # Display jobs by education level

# %%
for job_id in jobs_info:
    job = jobs_info[job_id]
    if job.education_level_required == 'Técnico':
        print("\n---")
        print(job_id)
        print(job.title)
        print(job.domains)
        print(job.job_description)
# Out:
# ---
# j100
# Legal Intern – Negotiation & Research
# ['Legal Research And Procedural Support']
# Legal Intern – Negotiation & Research will conduct legal research on complex cases and regulatory matters, support contract negotiations and client discussions, draft legal documents, briefs, and correspondence, and analyze case law to prepare detailed research summaries.
#
#
# ---
# j102
# Junior Legal Specialist – Statutory Review
# ['Legal Research And Procedural Support']
# Analyzes and interprets statutory requirements, reviews legislation and regulatory frameworks, and prepares summaries of legal requirements for internal teams. Works closely with senior legal counsel and compliance teams to ensure accurate interpretation of laws and regulations.
#
#
# ---
# j106
# Junior Legal Analyst – Ethics & Drafting
# ['Legal Research And Procedural Support']
# Junior Legal Analyst – Ethics & Drafting in Curitiba, Brazil, supporting legal research, document drafting, and contract reviews while ensuring ethical compliance and adherence to professional standards. The role involves assisting with case preparation, maintaining organized case files, and collaborating with senior analysts on legal projects.
#
#
# ---
# j107
# Legal Analyst – Client Counseling & Negotiation
# ['Legal Research And Procedural Support']
# Legal Analyst – Client Counseling & Negotiation in Porto Alegre, Brazil. Analyzes legislation and legal documents to provide compliance guidance, counsels clients on legal matters, and assists in contract negotiations and dispute resolution. Focuses on interpreting complex legal requirements and supporting clients through legal processes.
#
#
# ---
# j113
# Port Logistics Specialist – Yard & Gate
# ['Maritime And Port Operations Management']
# The Port Logistics Specialist – Yard & Gate manages maritime terminal operations, coordinating container movements, yard space optimization, and gate processes to ensure efficient cargo flow and regulatory compliance. The role involves processing shipments, verifying documentation, scheduling vehicles, and enforcing safety and security protocols.
#
#
# ---
# j116
# Maritime Ground Operations Consultant
# ['Maritime And Port Operations Management']
# The Maritime Ground Operations Consultant optimizes port operations and logistics in Salvador, ensuring efficient cargo flow between vessels and ground transportation. The role involves planning supply chain activities, enforcing safety and compliance standards, and coordinating dispatch schedules to minimize delays and maximize throughput.
#
#
# ---
# j119
# Terminal Coordination Specialist
# ['Maritime And Port Operations Management']
# Terminal Coordination Specialist manages daily port terminal operations, coordinating vessel arrivals and departures, cargo handling, and logistics to ensure smooth and compliant maritime activities. Works closely with ship crews, cargo handlers, and port authorities to maintain efficient terminal workflows and safety protocols.
#
#
# ---
# j12
# Administrative Assistant
# ['Financial Operations And Compliance Management']
# Administrative Assistant – Banking Services in Porto Alegre, responsible for managing and organizing banking documents, handling sensitive financial information securely, coordinating inter-departmental communication, and supporting daily banking operations.
#
#
# ---
# j124
# Onboard Safety Supervisor – Crew & Passengers
# ['Maritime And Port Operations Management']
# Onboard Safety Supervisor – Crew & Passengers ensures safety standards and protocols for crew and passengers during maritime and river transport operations. Responsibilities include monitoring safety procedures, conducting safety briefings, and ensuring compliance with maritime regulations. Works closely with the captain, crew, and passenger service teams to maintain a secure environment throughout each journey.
#
#
# ---
# j125
# Analyst – Maritime Operations & Maintenance
# ['Maritime And Port Operations Management']
# Analyst – Maritime Operations & Maintenance: Optimize vessel operations, ensure regulatory compliance, and drive efficiency improvements in maritime and river transport by analyzing operational data, supporting maintenance scheduling, and upholding international safety and environmental standards.
#
#
# ---
# j126
# Maritime Consultant – Shipboard Efficiency & Risk
# ['Maritime And Port Operations Management']
# Optimize vessel operations, manage safety protocols, and assess operational risks in maritime settings. Analyze shipboard efficiency, conduct risk assessments, and implement emergency safety measures. Collaborate with ship crews, port authorities, and maritime teams to ensure safe and efficient vessel operations.
#
#
# ---
# j128
# Marine Systems Analyst – Performance & Compliance
# ['Maritime And Port Operations Management']
# **Marine Systems Analyst – Performance & Compliance**
#
# Monitor vessel performance metrics, ensure regulatory compliance, and coordinate between ship crews, port authorities, and technical teams. Analyze engine data, maintain compliance records, and support troubleshooting of marine systems. Prepare reports for regulatory inspections and audits.
#
#
# ---
# j134
# Production Trainee – Line Operations
# ['Industrial Production And Live Event Technical Operations']
# Production Trainee – Line Operations in Fortaleza, Brazil. This entry-level role involves supporting daily production line operations, learning to operate and maintain industrial equipment safely, assisting with basic maintenance, and documenting production data. The trainee will follow safety protocols, participate in continuous improvement initiatives, and work under supervision to gain hands-on experience in manufacturing processes, including metalworking and hydraulic/pneumatic systems. No prior work experience is required.
#
#
# ---
# j135
# Manufacturing Coordinator – Tools & Setup
# ['Industrial Production And Live Event Technical Operations']
# Manufacturing Coordinator – Tools & Setup: Coordinates tool management and equipment setup in production operations, ensuring smooth manufacturing processes. Responsibilities include maintaining tools, troubleshooting equipment issues, performing repairs, supporting electrical system maintenance, and collaborating with production teams to minimize downtime. The role involves coordinating tool inventory, documenting processes, and maintaining accurate records to support efficient production.
#
#
# ---
# j139
# Safety Compliance Assistant – Production
# ['Health Safety And Environmental Compliance']
# Safety Compliance Assistant in Production and Collective Equipment, ensuring regulatory compliance and workplace safety by monitoring safety standards, maintaining documentation, and supporting training programs. Collaborates with production teams to uphold a safe working environment. Remote position based in Brazil, requiring Portuguese fluency.
#
#
# ---
# j142
# Procurement Analyst – Vendor Selection
# ['Procurement And Supplier Management']
# Procurement Analyst responsible for evaluating and selecting vendors, managing supplier relationships, and overseeing contracts to optimize supply chain efficiency and reduce costs.
#
#
# ---
# j143
# Junior Supply Chain Risk Specialist
# ['Procurement And Supplier Management']
# **Junior Supply Chain Risk Specialist:** Analyze supplier relationships to identify vulnerabilities, mitigate supply chain disruptions, and strengthen procurement operations. Contribute to resilient procurement processes, inform strategic decisions on supplier diversification, and support business continuity.
#
#
# ---
# j146
# Consultant – Procurement & ERP Systems
# ['Procurement And Supplier Management']
# Consultant – Procurement & ERP Systems: Optimize procurement processes and technology solutions by implementing and enhancing ERP systems, strengthening supplier relationships, and guiding digital transformation initiatives to modernize purchasing workflows and improve efficiency.
#
#
# ---
# j15
# Financial Administration Consultant
# ['Financial Operations And Compliance Management']
# Financial Administration Consultant in Brasília to prepare and submit regulatory reports, analyze financial data for banking and insurance operations, support administrative processes, and collaborate on accurate record-keeping and reporting standards.
#
#
# ---
# j153
# Lighting & Rigging Assistant
# ['Industrial Production And Live Event Technical Operations']
# The Lighting & Rigging Assistant supports show production by setting up and managing lighting equipment, assisting with rigging, and ensuring smooth live event operations. The role involves organizing cables, mounting lighting systems, monitoring performance, and maintaining safety compliance during shows.
#
#
# ---
# j155
# AV & Lighting Analyst – Show Support
# ['Industrial Production And Live Event Technical Operations']
# AV & Lighting Analyst responsible for ensuring optimal audiovisual and lighting setups during live performances. Works closely with production crews and performers to maintain clear communication and organized technical systems. Supports seamless live experiences by managing equipment and adapting quickly under pressure. Based in Salvador, Brazil.
#
#
# ---
# j157
# Technical Coordinator – Lighting & Video
# ['Industrial Production And Live Event Technical Operations']
# Technical Coordinator – Lighting & Video coordinates lighting and video systems for live events, ensuring smooth technical execution. Oversees rigging, troubleshoots issues, and collaborates with production teams to deliver flawless performances.
#
#
# ---
# j158
# Lighting Rigging Coordinator
# ['Industrial Production And Live Event Technical Operations']
# The Lighting Rigging Coordinator oversees the setup, coordination, and maintenance of lighting equipment and rigging systems for live events and productions in Brasília. Responsibilities include planning and executing lighting rigging installations, coordinating with technical crews for proper equipment placement and safety, managing daily rigging operations, troubleshooting issues, conducting safety inspections, and maintaining documentation of equipment status and configurations.
#
#
# ---
# j161
# Social Program Assistant
# ['Community Engagement And Cultural Development']
# Support community programs and educational initiatives in Fortaleza by coordinating activities, assisting with documentation, and engaging with participants and stakeholders to ensure smooth and effective program implementation.
#
#
# ---
# j162
# Community Development Analyst
# ['Community Engagement And Cultural Development']
# Analyze community needs and program effectiveness to support social, educational, and cultural initiatives in São Paulo, ensuring meaningful impact through data-driven insights and stakeholder collaboration.
#
#
# ---
# j166
# Consultant – Community Engagement Strategy
# ['Community Engagement And Cultural Development']
# Consultant – Community Engagement Strategy in Curitiba to develop and implement strategies that connect communities with social, educational, and cultural initiatives. The role involves designing tailored engagement approaches, facilitating workshops, analyzing community needs, creating outreach plans, and evaluating impact. The consultant will build relationships with local leaders, organizations, and institutions to foster meaningful participation and lasting community impact.
#
#
# ---
# j17
# Insurance Administration Manager
# ['Insurance Operations And Compliance Management']
# The Insurance Administration Manager oversees administrative operations in the insurance division, managing policy processing, claims administration, and record maintenance while ensuring data security, regulatory compliance, and efficient cross-departmental coordination.
#
#
# ---
# j171
# Reception & Customer Service Assistant – Tourism
# ['Tourism And Hospitality Guest Services']
# The Reception & Customer Service Assistant – Tourism serves as the primary point of contact for tourists in Curitiba, providing information on local attractions, accommodations, and services while ensuring exceptional customer experiences. The role involves handling inquiries, resolving concerns, maintaining visitor records, and supporting promotional activities to enhance guest satisfaction during their stay.
#
#
# ---
# j173
# Destination Promotion Assistant – Digital Presence
# ['Tourism And Hospitality Guest Services']
# The Destination Promotion Assistant – Digital Presence will support tourism promotion by managing digital content and online presence for Fortaleza, showcasing local attractions and cultural experiences through various digital channels. Responsibilities include creating engaging content, maintaining online visibility, and collaborating with local businesses to promote authentic experiences.
#
#
# ---
# j175
# Tourism Programs Coordinator – Partnerships
# ['Tourism And Hospitality Guest Services']
# **Tourism Programs Coordinator – Partnerships** manages tourism programs and builds strategic partnerships to enhance visitor experiences in Fortaleza. The role involves coordinating events, developing marketing strategies for local attractions, and delivering exceptional customer service to visitors and partners. Collaboration with local businesses, tourism operators, and community organizations is key to creating compelling tourism offerings. The position requires in-person work in Fortaleza to engage directly with tourists and stakeholders.
#
#
# ---
# j176
# Tourism Consultant – Market Development
# ['Tourism And Hospitality Guest Services']
# Tourism Consultant – Market Development in Brasília, focusing on expanding market reach and developing promotional strategies to connect travelers with authentic tourism experiences. Responsibilities include creating marketing campaigns, managing digital channels, building partnerships with tourism stakeholders, analyzing market trends, and developing promotional materials to highlight regional attractions. The role involves regular interaction with local tourism stakeholders and may require travel within the region.
#
#
# ---
# j179
# Customer Care Coordinator – Tourism
# ['Tourism And Hospitality Guest Services']
# The Customer Care Coordinator – Tourism handles customer interactions and support for travelers and tourism clients, resolving booking issues, travel concerns, and service-related questions. The role involves coordinating with tourism partners, maintaining high customer satisfaction, and providing detailed information about tourism services and destinations. This remote position serves clients in Brazil, requiring fluent Portuguese communication skills.
#
#
# ---
# j184
# Fleet Coordination Trainee
# ['Maritime And Port Operations Management']
# Fleet Coordination Trainee responsible for learning to oversee vehicle operations, track fleet performance, and support daily logistics coordination. Duties include coordinating vehicle schedules, assisting with maintenance tracking, supporting dispatch operations, monitoring vehicle locations, and maintaining records of fleet activities and performance metrics. The role involves hands-on training in fleet management systems and procedures.
#
#
# ---
# j191
# Visual Arts Intern – Art History & Color
# ['Visual Arts And Studio Production']
# The Visual Arts Intern – Art History & Color will support art historical research, cataloging and analyzing works from various periods and movements. The role involves developing color palettes, coordinating color schemes for visual projects, and documenting artistic processes. Additionally, the intern will maintain visual archives and assist with exhibitions or displays.
#
#
# ---
# j26
# Consultant – Documentation Strategy
# ['Cultural Information And Records Management']
# Consultant – Documentation Strategy: Design and implement documentation frameworks to preserve cultural heritage and business records, ensuring long-term accessibility and compliance. Develop digital preservation strategies, retention protocols, and version control systems to optimize information management and reduce risks.
#
#
# ---
# j27
# Records & Culture Documentation Manager
# ['Cultural Information And Records Management']
# **Records & Culture Documentation Manager** responsible for organizing and maintaining cultural documentation and records systems, ensuring institutional knowledge is accessible and compliant with regulations. Works closely with cross-functional teams to preserve organizational culture and knowledge in São Paulo.
#
#
# ---
# j3
# Financial Reporting Analyst
# ['Financial Operations And Compliance Management']
# Prepare and analyze financial reports to support business decisions, conduct risk assessments, interpret financial data for stakeholders, and ensure compliance with reporting standards through auditing support.
#
#
# ---
# j31
# Assistant – Design Research Projects
# ['Design Research And Innovation Management']
# Support design research initiatives, assist in data collection and analysis for user experience studies, coordinate research activities, and contribute to findings that shape product and service design decisions.
#
#
# ---
# j38
# Research & Development Supervisor
# ['Design Research And Innovation Management']
# The **Research & Development Supervisor** leads the Design Research Studies and Development team in Salvador, overseeing research projects from concept to implementation. The role involves supervising research initiatives, coordinating cross-functional teams, managing timelines and resources, and ensuring research methodologies meet industry standards. The supervisor reviews project outcomes, presents findings to stakeholders, and identifies process improvements. The position requires strong leadership, problem-solving skills, and the ability to translate complex data into actionable insights. The role also involves mentoring talent and driving innovation in research projects.
#
#
# ---
# j40
# Electronics Designer Intern
# ['Electrical And Electronics Systems Engineering']
# Electronics Designer Intern to support electronic system design and testing projects, working with electronic systems, applying troubleshooting techniques, and gaining practical experience with industry-standard test equipment.
#
#
# ---
# j41
# Electrical Assistant Technician
# ['Electrical And Electronics Systems Engineering']
# Electrical Assistant Technician supports electrical systems and equipment maintenance, focusing on microcontroller-based projects, including installations, repairs, and troubleshooting. Works closely with senior technicians to ensure proper system functionality.
#
#
# ---
# j42
# Electronics Analyst – Testing & Debugging
# ['Electrical And Electronics Systems Engineering']
# Electronics Analyst responsible for testing and debugging electronic systems, including complex circuits and microcontroller programming. The role involves identifying performance issues, analyzing component behavior, designing and modifying circuits, and documenting findings. Collaboration with engineering teams is essential to resolve technical challenges and ensure system integration. On-site work in Fortaleza is required for direct access to laboratory equipment.
#
#
# ---
# j43
# Power Systems Specialist
# ['Electrical And Electronics Systems Engineering']
# Maintain and troubleshoot electrical power systems with precision and safety in Rio de Janeiro, focusing on electronics and electrical systems expertise.
#
#
# ---
# j44
# Software-Focused Electrical Intern
# ['Electrical And Electronics Systems Engineering']
# **Software-Focused Electrical Intern** will design simple circuits, perform basic soldering, and test electrical components while assisting with hardware-software interface development. The role involves troubleshooting electrical issues, documenting project progress, and participating in design reviews to build technical skills. The internship focuses on bridging electrical hardware and software development in a remote setting.
#
#
# ---
# j46
# Consultant – Electrical Systems Design
# ['Electrical And Electronics Systems Engineering']
# Consultant – Electrical Systems Design: Guide clients through complex electrical system projects, from concept to implementation, by analyzing requirements, designing solutions, and ensuring compliance with technical and safety standards. Tasks include interpreting electrical schematics, performing intermediate-level soldering for prototypes and repairs, and diagnosing electronic system issues. Work directly with clients to understand their needs and provide expert recommendations.
#
#
# ---
# j49
# Embedded Systems Specialist
# ['Electrical And Electronics Systems Engineering']
# Embedded Systems Specialist to work with electronic systems, troubleshoot technical issues, and develop practical skills in embedded systems by diagnosing and fixing electronic system problems.
#
#
# ---
# j53
# Specialist – Fiber Quality Control
# ['Fiber And Paper Manufacturing Operations']
# Ensures fiber and paper product quality by monitoring production, conducting tests, and optimizing processes to maintain consistency and standards in manufacturing. Supports product development by analyzing fiber characteristics and recommending process improvements.
#
#
# ---
# j6
# Accounting Assistant – Compliance & Reporting
# ['Financial Operations And Compliance Management']
# Accounting Assistant – Compliance & Reporting ensures financial operations meet regulatory standards by preparing and reviewing accurate financial reports, monitoring adherence to accounting standards, supporting month-end and year-end reporting, and maintaining documentation for audit trails and compliance reviews.
#
#
# ---
# j65
# Junior Food Manufacturing Coordinator
# ['Food Production Quality And Safety Management']
# The Junior Food Manufacturing Coordinator supports food production operations by coordinating manufacturing processes and supply chain activities. The role involves scaling recipes to meet production demands, sourcing raw materials, coordinating production schedules, and maintaining accurate records of production and material usage. This remote position is designed for recent graduates with a technical degree and fluent Portuguese (Brazilian) to communicate with suppliers and team members.
#
#
# ---
# j68
# Nutrition & Food Technology Analyst
# ['Food Production Quality And Safety Management']
# Analyze food production processes to optimize efficiency and reduce waste, monitoring workflows, implementing waste reduction strategies, and ensuring quality standards in manufacturing operations. Collaborate with production managers, quality control teams, and operations staff to streamline processes and minimize resource waste.
#
#
# ---
# j69
# Specialist – Food Innovation
# ['Food Production Quality And Safety Management']
# Specialist – Food Innovation will drive product development and process optimization in food manufacturing, scaling recipes for commercial production while maintaining quality standards and reducing operational waste. The role involves overseeing production lines, implementing sustainability initiatives, and ensuring adherence to food safety standards.
#
#
# ---
# j76
# Hospitality Consultant – Guest Relations
# ['Tourism And Hospitality Guest Services']
# Hospitality Consultant – Guest Relations ensures exceptional guest experiences by managing arrivals, departures, and front desk operations in Salvador. The role involves handling registrations, assisting with luggage and requests, and providing local expertise on attractions, restaurants, and cultural highlights to enhance guest satisfaction.
#
#
# ---
# j83
# HSE Assistant – Site Inspections
# ['Health Safety And Environmental Compliance']
# Conducts safety inspections at industrial sites in Belo Horizonte, identifying hazards, documenting violations, and recommending corrective actions to ensure compliance with workplace safety standards. Collaborates with site supervisors and safety managers to maintain and improve safety protocols.
#
#
# ---
# j89
# Hazardous Materials Analyst – HSE
# ['Health Safety And Environmental Compliance']
# Hazardous Materials Analyst – HSE will assess and manage dangerous substance protocols in industrial environments, ensuring compliance with safety standards and regulatory requirements. The role involves analyzing hazardous material risks, maintaining detailed documentation, and following safety protocols to protect workplace health, safety, and environmental standards.
#
#
# ---
# j9
# Accounting Manager – Risk & Reporting
# ['Financial Operations And Compliance Management']
# **Accounting Manager – Risk & Reporting:** Develop and maintain risk reporting frameworks, conduct cost analysis to support budget planning, transform financial data into strategic insights, and ensure regulatory compliance and strong internal controls.
#
#
# ---
# j90
# Insurance Intern – Claims & Policies
# ['Insurance Operations And Compliance Management']
# Insurance Intern responsible for supporting claims processing and policy management, handling client inquiries, and assisting with insurance product sales. The role involves managing policy details, providing customer support, and gaining experience in actuarial principles and insurance operations.
#
#
# ---
# j94
# Insurance Operations Trainee
# ['Insurance Operations And Compliance Management']
# Insurance Operations Trainee in Rio de Janeiro responsible for learning and applying compliance procedures, monitoring policy adherence, assessing risk, detecting fraud, and handling customer inquiries related to insurance policies. The role focuses on training in regulatory requirements, fraud detection, and client support within the Brazilian insurance market.
#
#
# ---
# j95
# Coordinator – Insurance Compliance
# ['Insurance Operations And Compliance Management']
# **Coordinator – Insurance Compliance** in Belo Horizonte ensures insurance policies meet regulatory standards, supporting underwriting processes by reviewing applications, maintaining compliance, and coordinating documentation. The role involves direct collaboration with compliance and underwriting teams to uphold regulatory excellence while serving clients.
#
#
# ---
# j96
# Insurance Consultant – Risk & Strategy
# ['Insurance Operations And Compliance Management']
# **Insurance Consultant – Risk & Strategy**
#
# Guide clients through complex insurance decisions by analyzing risk factors and developing strategic coverage solutions. Evaluate and underwrite insurance policies, provide customer service, and support sales and marketing efforts. Apply actuarial principles to assess risk and pricing scenarios. Serve a diverse client base in Portuguese and English. Based in Porto Alegre, with in-person collaboration.
#
#
# ---
# j97
# Insurance Services Manager
# ['Insurance Operations And Compliance Management']
# **Insurance Services Manager** responsible for transforming insurance services by analyzing pricing data, detecting fraud, ensuring regulatory compliance, and driving sales and marketing efforts to expand insurance coverage access.
